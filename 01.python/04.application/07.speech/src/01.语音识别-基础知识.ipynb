# %% [markdown]
# # 基本流程

# %% [markdown]
# 语音识别（Speech Recognition）是指通过计算机技术将语音信号转换为文本信息的过程。它涉及语音信号的捕捉、特征提取、模式识别等多个技术环节。语音识别广泛应用于各种场景，如智能助手（Siri、Google Assistant）、语音输入、语音翻译、自动客服、智能家居控制等。
#
# 语音识别的基本流程：
#
# 语音采集：
#
# - 使用麦克风或其他设备采集用户的语音信号，将声音信号转化为数字化的音频波形。
#
# 预处理：
#
# - 对采集到的语音信号进行噪声去除、回声消除、增强信号等预处理操作，提高语音质量。
#
# - 分帧处理：将连续的语音信号划分为短时帧，以便后续处理。
# - 窗函数：通常会对每一帧加窗，减少信号边缘的不连续性。
#
#
# 特征提取：
#
# - 语音信号被转换为一系列特征，用来表示声音的时频信息，常见的特征有：
#     - 梅尔频率倒谱系数（MFCC）：一种常用的特征表示方法，能够模拟人耳的听觉感知。
#     - 线性预测编码（LPC）：用于模拟语音信号的声道模型。
#     - Chroma特征、音高等其他特征。
#
# 声学模型：
#
# - 声学模型用于将音频特征映射到可能的语音单元（如音素、词或子词）。常用的声学模型包括：
#
#     - 隐马尔可夫模型（HMM）：传统的模型，能够处理语音信号的时序特性。
#     - 深度神经网络（DNN）：深度学习模型对语音信号的建模能力更强，能够学习复杂的时序特征。
#     - 卷积神经网络（CNN）：用于提取音频信号中的空间特征，近年来也在语音识别中应用。
#     - 循环神经网络（RNN）：特别是LSTM（长短时记忆网络）和GRU（门控循环单元）用于处理长时序数据，适合语音识别中的时序依赖问题。
#
# 语言模型：
#
# - 语言模型用于对识别结果进行后处理，帮助确定最有可能的语音序列。语言模型通常基于大规模的文本数据进行训练，用来评估词序列的流畅度和语法合理性。
#
# - 常见的语言模型有：
#     - n-gram模型：通过统计文本中n个词的出现概率来估计词序列的概率。
#     - 神经网络语言模型：如基于LSTM、Transformer等模型的语言模型，能够捕捉长程依赖关系。
#
# 解码和输出：
#
# - 在识别过程中，解码器结合声学模型和语言模型，使用搜索算法（如Viterbi算法）从可能的音素或词序列中选择最匹配的文本输出。

# %% [markdown]
# # 预处理

# %% [markdown]
# 语音识别中的预处理手段是将原始语音信号转换为适合后续特征提取和模型训练的数据的重要步骤。预处理技术能够减少噪声、增强信号质量，提升语音识别系统的准确性和鲁棒性。以下是常见的语音预处理手段的详细介绍：

# %% [markdown]
# ## 时域处理

# %% [markdown]
# ![image.png](attachment:ee3ef889-4ea0-412b-b9bd-0483546a2862.png)

# %% [markdown]
# ## 频域处理

# %% [markdown]
# ![image.png](attachment:e6e1649d-db77-48d9-905d-f74f52d2fa6d.png)

# %% [markdown]
# # 特征提取

# %% [markdown]
# 特征提取是语音识别的核心步骤，其目的是将原始语音信号转换为能够被机器学习模型理解的表示形式。这些特征通常包括频率、能量、时序等属性，能够反映语音的物理和语义信息。以下是常用的语音信号特征提取方法：

# %% [markdown]
# ## 时域特征提取

# %% [markdown]
# ![image.png](attachment:a932be66-3d1c-4352-86ea-d87c2d4fd949.png)

# %% [markdown]
# ## 频域特征提取

# %% [markdown]
# ![image.png](attachment:c767f6c0-c201-4ea8-aba0-749bebe3a386.png)

# %% [markdown]
# ## 倒谱特征提取

# %% [markdown]
# ![image.png](attachment:5fc47c44-d6d1-4e8a-a4b4-3d013ef729bd.png)

# %% [markdown]
# ## 时频联合特征提取

# %% [markdown]
# ![image.png](attachment:6119f582-894b-4aa2-a58f-23bdb641b96f.png)

# %% [markdown]
# # 模型介绍

# %% [markdown]
# ## 传统语音识别模型

# %% [markdown]
# ![image.png](attachment:27ce4987-3735-45dc-b0ce-9557586c27d5.png)

# %% [markdown]
# ## 基于深度学习的语音识别模型

# %% [markdown]
# ![image.png](attachment:06a2af3e-3ec6-44fa-86b7-5d98644b9603.png)
# ![image.png](attachment:deb1f88a-fdfb-4705-8d4c-050b1898e1cb.png)
# ![image.png](attachment:c0259b38-b596-41d3-969b-9035a3ebbf7f.png)
# ![image.png](attachment:c9a3ec25-d4b5-464d-9277-ce0218d3d080.png)
# ![image.png](attachment:17e323f2-caec-4017-86c5-77152259a971.png)
